# %% [markdown]
# ## To analyze the age distribution of  Titanic passengers by dividing them into three main categories — Children, Adults, and Senior — to understand which group formed the majority on board

# %%
# Define 3 age categories
bins = [0, 18, 60, 100]
labels = ['Child', 'Adult', 'Senior']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
# Count of each age group
age_counts = df['AgeGroup'].value_counts()
age_counts
# Out:
# AgeGroup
# Adult     730
# Child     139
# Senior     22
# Name: count, dtype: int64

# %%
# Plot bar chart
age_counts.plot(kind='bar', color=['skyblue', 'lightgreen', 'orange'], edgecolor='black')
plt.title("Age Distribution of Titanic Passengers")
plt.xlabel("Age Category")
plt.ylabel("Number of Passengers")
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0   38      1
# 2                               Heikkinen, Miss. Laina    0   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0   35      1
# 4                             Allen, Mr. William Henry    1   35      0
# ..                                                 ...  ...  ...    ...
# ...

# %% [markdown]
# ## To study the Gender Distribution of passengers aboard the Titanic and identify which gender group had a higher representation across classes.

# %%
# Count gender values
gender_counts = df['Sex'].value_counts()
print("\nGender Distribution:\n", gender_counts)
# Out:
# Gender Distribution:
#  Sex
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
# Plot gender distribution
plt.figure(figsize=(6,4))
sns.countplot(x='Sex', data=df, palette='pastel', edgecolor='black')
plt.title('Gender Distribution on Titanic')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23696\4213607410.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=df, palette='pastel', edgecolor='black')

# %% [markdown]
# ## To analyze the Passenger Class Distribution (Pclass) on the Titanic and understand which socio-economic groups formed the majority of passengers.

# %%
class_counts = df['Pclass'].value_counts()
class_counts
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Pclass', data=df, palette='muted', edgecolor='black')
plt.title('Passenger Class Distribution on Titanic')
plt.xlabel('Passenger Class (1 = First, 2 = Second, 3 = Third)')
plt.ylabel('Number of Passengers')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23696\1882515445.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass', data=df, palette='muted', edgecolor='black')

# %%
# Calculate survival rate by class
class_survival = df.groupby('Pclass')['Survived'].mean().round(2)
print("\nClass-wise Survival Rate:\n", class_survival)
# Out:
# Class-wise Survival Rate:
#  Pclass
# 1    0.63
# 2    0.47
# 3    0.24
# Name: Survived, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Survived', data=df, palette='coolwarm')
plt.title('Titanic Survival Distribution')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Number of Passengers')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23696\3394505820.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=df, palette='coolwarm')

# %% [markdown]
# ## The sinking of the Titanic in 1912 resulted in the loss of many lives. Survival on the ship was not uniform and depended on several factors, including passenger class, age, and gender. This study focuses on analyzing the impact of passenger class (Pclass) on survival rate.

# %%
class_survival_rate = df.groupby('Pclass')['Survived'].mean() * 100
class_survival_rate
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
colors = ['gold', 'silver', 'brown']
labels = ['1st Class', '2nd Class', '3rd Class']

plt.figure(figsize=(7,7))
plt.pie(class_survival_rate,autopct='%1.1f%%', explode=(0.05,0.05,0.05), shadow=True)
plt.title('Titanic: Class-wise Survival Rate')
plt.show()

# %%
avg_fare_per_class = df.groupby('Pclass')['Fare'].mean()
print("Average Fare per Class:\n", avg_fare_per_class)
# Out:
# Average Fare per Class:
#  Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
# Boxplot for fare distribution by class
plt.figure(figsize=(8,6))
sns.boxplot(x='Pclass', y='Fare', data=df, palette=['gold', 'silver', 'brown'])
plt.title('Titanic: Fare Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23696\2823370239.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Pclass', y='Fare', data=df, palette=['gold', 'silver', 'brown'])

# %% [markdown]
# ## The Titanic passengers boarded from three main ports: Southampton (S), Cherbourg (C), and Queenstown (Q). Passenger demographics, class, and fare varied significantly by port, reflecting differences in economic status and age groups.

# %%
embark_stats = df.groupby('Embarked').agg({'Age':'mean', 'Fare':'mean', 'Pclass':'count'}).rename(columns={'Pclass':'PassengerCount'})
embark_stats
# Out:
#                 Age       Fare  PassengerCount
# Embarked
# C         30.654762  59.954144             168
# Q         29.324675  13.276030              77
# S         29.594427  27.243651             646

# %%
# Bar plot: Number of passengers per Embarkation
plt.figure(figsize=(7,5))
sns.countplot(x='Embarked', data=df, palette='Set2')
plt.title('Number of Passengers per Embarkation Port')
plt.xlabel('Embarkation Port')
plt.ylabel('Passenger Count')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23696\1402813107.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Embarked', data=df, palette='Set2')

# %%
plt.figure(figsize=(7,5))
sns.violinplot(x='Embarked', y='Fare', data=df)
plt.title('Fare Distribution by Embarkation Port')
plt.xlabel('Embarkation Port')
plt.ylabel('Fare')
plt.show()

# %%
# Boxplot: Age by Embarkation
plt.figure(figsize=(7,5))
sns.boxplot(x='Embarked', y='Age', data=df, palette='Set1')
plt.title('Age Distribution by Embarkation Port')
plt.xlabel('Embarkation Port')
plt.ylabel('Age')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23696\3566393113.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Embarked', y='Age', data=df, palette='Set1')

# %%
# Total family members aboard (SibSp + Parch)
df['FamilySize'] = df['SibSp'] + df['Parch']

# %%
# Number of solo travelers vs family travelers
solo_travelers = df[df['FamilySize'] == 0].shape[0]
family_travelers = df[df['FamilySize'] > 0].shape[0]

print("Solo Travelers:", solo_travelers)
print("Family Travelers:", family_travelers)
# Out:
# Solo Travelers: 537
# Family Travelers: 354

# %% [markdown]
# ## The Titanic dataset shows whether passengers traveled alone or with family.

# %%
# Prepare FamilySize and TravelType
df['FamilySize'] = df['SibSp'] + df['Parch']
df['TravelType'] = df['FamilySize'].apply(lambda x: 'Solo' if x == 0 else 'Family')

# %%
# Count of Solo vs Family travelers
travel_count = df['TravelType'].value_counts()
travel_count
# Out:
# TravelType
# Solo      537
# Family    354
# Name: count, dtype: int64

# %%
# Simple bar chart
plt.figure(figsize=(6,5))
plt.bar(travel_count.index, travel_count.values, color=['skyblue','salmon'], edgecolor='black')
plt.title('Titanic: Solo vs Family Travelers')
plt.ylabel('Passenger Count')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.pie(travel_count.values, labels=travel_count.index, autopct='%1.1f%%')
centre = plt.Circle((0,0),0.4,fc='white')
plt.gca().add_artist(centre)
plt.title("Solo vs Family Travelers (Donut Chart)")
plt.show
